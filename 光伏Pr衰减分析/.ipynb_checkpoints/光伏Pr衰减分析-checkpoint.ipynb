# %% [markdown]
# # 光伏Performance ratio(Pr)值年衰减分析
#
# 一个光伏电站组件的Pr值测算，对于估算项目的成本，组件的采购及未来的投资回收期都有重要的意义。
# 但是大部分时间，除了一开始组件供应商提供的Pr保证外，很多项目运营人员很难通过大量的现场光伏监测数据获得组件实际的Pr衰减情况。
#
# 为此，我们小组参考了rdtools模块的介绍案例，基于光伏电站的发电量数据对光伏电站的pr衰减值进行了分析
#
# Pr值的测算主要分成了以下几个步骤：<br>
#      1.初始计算<br>
#      2.数据标准化<br>
#      3.数据过滤<br>
#      4.数据聚合<br>
#      5.Pr计算<br>
#
# 本次分析数据源来自the Desert Knowledge Australia Solar Centre的Site 12光伏电站文件，可以在以下链接中下载，或者本仓库master分支DATA目录下下载
#
# https://dkasolarcentre.com.au/source/alice-springs/dka-m5-b-phase

# %%
'''
导入评价光伏电站Pr衰减的包
'''
import rdtools

# %%
import datetime
from collections import Counter
from collections import OrderedDict
from datetime import timedelta
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pvlib
# %matplotlib inline
#使用%matplotlib命令可以将matplotlib的图表直接嵌入到Notebook之中，或者使用指定的界面库显示图表，它有一个参数指定matplotlib图表的显示方式。inline表示将图表嵌入到Notebook中。

#导入可以将数据转化为时间的模块
from pandas.plotting import register_matplotlib_converters

# 注册转换器，以便 matplotlib 可以理解 pandas 的时间序列格式
register_matplotlib_converters()
print(register_matplotlib_converters)

#定义绘图格式
import matplotlib
matplotlib.rcParams.update({'font.size': 12,
                           'figure.figsize': [9, 6],
                           'lines.markeredgewidth': 0,
                           'lines.markersize': 2
                           })

print(dir(pvlib.pvsystem)) #本项目将要用到此库中的函数
# Out:
# <function register at 0x00000264AC30B160>
# ['DC_MODEL_PARAMS', 'LocalizedPVSystem', 'Location', 'OrderedDict', 'PVSystem', 'TEMP_MODEL_PARAMS', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_build_kwargs', '_parse_raw_sam_df', '_singlediode', 'adrinverter', 'ashraeiam', 'atmosphere', 'calcparams_cec', 'calcparams_desoto', 'calcparams_pvsyst', 'division', 'i_from_v', 'io', 'irradiance', 'max_power_point', 'np', 'os', 'pd', 'physicaliam', 'pvsyst_celltemp', 'pvwatts_ac', 'pvwatts_dc', 'pvwatts_losses', 'retrieve_sam', 'sapm', 'sapm_aoi_loss', 'sapm_celltemp', 'sapm_effective_irradiance', 'sapm_spectral_loss', 'scale_voltage_current_power', 'singlediode', 'snlinverter', 'systemdef', 'tools', 'urlopen', 'v_from_i']

# %% [markdown]
# # 0：初始计算
#
# 这一部分主要是为光伏Pr衰减计算的rdtools包提供必要的数据,这一步暂时不会用到rdtools包。<br>
#
# rdtools包第一步需要做的工作是将获得的数据通过特定的性能指标进行标准化，这需要关于发电数据、组件温度、辐照度的时间记录，外加一部分原始数据（可见1：数据标准化）<br>
#
# 接下来的过程主要是加载表格数据，调整单元参数，为了后期统计方便重新定义列表名称。<br>
# 辐照传感器数据转换成组件计算的辐照度，并通过温度感应器的数据估算组件的温度。<br>

# %%
file_name = 'D:\\Jupyter-Lab\\Data-analysis\\DATA\\84-Site_DKA-M5_B-Phase.csv'
df=pd.read_csv(file_name)
print(df.columns)
# Out:
# Index(['timestamp', 'Active_Energy_Delivered_Received',
#        'Current_Phase_Average', 'Active_Power', 'Performance_Ratio',
#        'Wind_Speed', 'Weather_Temperature_Celsius',
#        'Weather_Relative_Humidity', 'Global_Horizontal_Radiation',
#        'Diffuse_Horizontal_Radiation', 'Wind_Direction',
#        'Weather_Daily_Rainfall', 'Radiation_Global_Tilted',
#        'Radiation_Diffuse_Tilted'],
#       dtype='object')

# %%
'''
更改列名，方便调用
'''
df = df.rename(columns={
    'Active_Power': 'power',  # 功率
    'Wind_Speed': 'wind',     # 风速
    'Weather_Temperature_Celsius': 'Tamb',  # 气温
    'Global_Horizontal_Radiation': 'ghi',  # 全球水平辐照度
    'Diffuse_Horizontal_Radiation': 'dhi'   # 扩散水平辐照度
})
print(df.columns)
# Out:
# Index(['timestamp', 'Active_Energy_Delivered_Received',
#        'Current_Phase_Average', 'power', 'Performance_Ratio', 'wind', 'Tamb',
#        'Weather_Relative_Humidity', 'ghi', 'dhi', 'Wind_Direction',
#        'Weather_Daily_Rainfall', 'Radiation_Global_Tilted',
#        'Radiation_Diffuse_Tilted'],
#       dtype='object')

# %%
'''
提供特定的坐标信息数据
pdc是系统的装机容量，这里5100代表的是5100w的电站，用的都是小组件
temp_model是组件模型，pvlib模块提供了6种组件模型，选择其中一种
'''
meta = {"latitude": -23.762028,
        "longitude": 133.874886,
        "timezone": 'Australia/North',
        "tempco": -0.005,
        "azimuth": 0, 
        "tilt": 20,
        "pdc": 5100.0,
        "temp_model": 'open_rack_cell_polymerback'}

# %%
'''
将df中的时间转换成指定的时间格式
并将时间列以时间列作为索引
便于后期切片或查找数据
'''
df.index = pd.to_datetime(df.timestamp)
print(df.index)
# Out:
# DatetimeIndex(['2008-09-12 05:55:00', '2008-09-12 06:00:00',
#                '2008-09-12 06:05:00', '2008-09-12 06:10:00',
#                '2008-09-12 06:15:00', '2008-09-12 06:20:00',
#                '2008-09-12 06:25:00', '2008-09-12 06:30:00',
#                '2008-09-12 06:35:00', '2008-09-12 06:40:00',
#                ...
#                '2018-09-04 08:15:00', '2018-09-04 08:20:00',
#                '2018-09-04 08:25:00', '2018-09-04 08:30:00',
#                '2018-09-04 08:35:00', '2018-09-04 08:40:00',
#                '2018-09-04 08:45:00', '2018-09-04 08:50:00',
#                '2018-09-04 08:55:00', '2018-09-04 09:00:00'],
#               dtype='datetime64[ns]', name='timestamp', length=1048575, freq=None)

# %%
'''
将时间按照时区本地化，这里换成了澳大利亚时区，
ambiguous='infer'代表如果出现空值，可以根据前后的值进行内插
'''
# 将df中的时间转换成指定的时间格式，并以时间列作为索引，便于后期切片或查找数据。
# 并把时间按照时区换成澳大利亚时区
df.index = pd.to_datetime(df.timestamp)
df.index = df.index.tz_localize(meta['timezone'], ambiguous = 'infer') 
print(df.index)
# Out:
# DatetimeIndex(['2008-09-12 05:55:00+09:30', '2008-09-12 06:00:00+09:30',
#                '2008-09-12 06:05:00+09:30', '2008-09-12 06:10:00+09:30',
#                '2008-09-12 06:15:00+09:30', '2008-09-12 06:20:00+09:30',
#                '2008-09-12 06:25:00+09:30', '2008-09-12 06:30:00+09:30',
#                '2008-09-12 06:35:00+09:30', '2008-09-12 06:40:00+09:30',
#                ...
#                '2018-09-04 08:15:00+09:30', '2018-09-04 08:20:00+09:30',
#                '2018-09-04 08:25:00+09:30', '2018-09-04 08:30:00+09:30',
#                '2018-09-04 08:35:00+09:30', '2018-09-04 08:40:00+09:30',
#                '2018-09-04 08:45:00+09:30', '2018-09-04 08:50:00+09:30',
#                '2018-09-04 08:55:00+09:30', '2018-09-04 09:00:00+09:30'],
#               dtype='datetime64[ns, Australia/North]', name='timestamp', length=1048575, freq=None)

# %%
'''
通过分析可以看到第一天的记录是在凌晨5:50开始的，由于是在夜里所以并没有发电信息的记录
因此我们可以删除掉所有发电功率为0的数据，dropna(subset['power'])
或者通过切片，选择了数据表第一天开始有记录数据的时间，至最后一天没有数据的时间
两种处理方式的效果一样，不过显然第一种处理之后的有效数据量更小
'''
df=df.dropna(subset=['power'])#删除掉所有发电功率为0的数据
#通过切片，选择了数据表最开始有记录数据的时间，至最后一天没有数据的时间

# %%
'''
将组件发电效率单位转换成w
输出1w组件最高的实际发电功率，竟达到了近1.1w
'''
df['power']=df.power*1000
print(df['power'].max()/5100)
# Out:
# 1.0950915019607843

# %%
'''
因为光伏区域夜晚不会发电，所以可以看到power列在晚间的发电量都是0
为保证数据连续，我们依据前几行的数据来推测数据变化的频率
这里得到的采样频率是5min.
'''
freq = pd.infer_freq(df.index[:10])
print(freq)
# Out:
# 5T

# %%
'''
以5min的频率进行重新采样，并记录这5min内所有数据的中位数
resample代表以5min对数据重新进行采样，如果之前数据采集的频率是1min，则median方法则会保留5组数据中的中值
'''
# 首先将 'timestamp' 列转换为 datetime 类型
df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y/%m/%d %H:%M', errors='coerce')

# 使用 resample 对数据进行重新采样，并计算中位数
df = df.resample(freq).median()

# 打印结果
print(df)
# Out:
#                                     timestamp  \
# timestamp
# 2008-09-12 05:55:00+09:30 2008-09-12 05:55:00
# 2008-09-12 06:00:00+09:30 2008-09-12 06:00:00
# 2008-09-12 06:05:00+09:30 2008-09-12 06:05:00
# 2008-09-12 06:10:00+09:30 2008-09-12 06:10:00
# 2008-09-12 06:15:00+09:30 2008-09-12 06:15:00
# ...                                       ...
# 2018-09-04 08:40:00+09:30 2018-09-04 08:40:00
# 2018-09-04 08:45:00+09:30 2018-09-04 08:45:00
# 2018-09-04 08:50:00+09:30 2018-09-04 08:50:00
# 2018-09-04 08:55:00+09:30 2018-09-04 08:55:00
# 2018-09-04 09:00:00+09:30 2018-09-04 09:00:00
#
#                            Active_Energy_Delivered_Received  \
# timestamp
# 2008-09-12 05:55:00+09:30                               0.0
# 2008-09-12 06:00:00+09:30                               0.0
# 2008-09-12 06:05:00+09:30                               0.0
# 2008-09-12 06:10:00+09:30                               0.0
# 2008-09-12 06:15:00+09:30                               0.0
# ...                                                     ...
# 2018-09-04 08:40:00+09:30                           89484.0
# 2018-09-04 08:45:00+09:30                           89484.0
# 2018-09-04 08:50:00+09:30                           89485.0
# 2018-09-04 08:55:00+09:30                           89485.0
# 2018-09-04 09:00:00+09:30                           89485.0
#
#                            Current_Phase_Average        power  \
# timestamp
# 2008-09-12 05:55:00+09:30               0.000000     0.000000
# 2008-09-12 06:00:00+09:30               0.000000     0.000000
# 2008-09-12 06:05:00+09:30               0.000000     0.000000
# 2008-09-12 06:10:00+09:30               0.000000     0.000000
# 2008-09-12 06:15:00+09:30               0.000000     0.000000
# ...                                          ...          ...
# 2018-09-04 08:40:00+09:30               7.647334  1805.866718
# 2018-09-04 08:45:00+09:30               8.038667  1902.600050
# 2018-09-04 08:50:00+09:30               8.437333  1998.066545
# 2018-09-04 08:55:00+09:30               8.809333  2087.866545
# 2018-09-04 09:00:00+09:30               9.146667  2170.666695
#
#                            Performance_Ratio  wind       Tamb  \
# timestamp
# 2008-09-12 05:55:00+09:30                NaN   NaN  25.734350
# 2008-09-12 06:00:00+09:30                NaN   NaN  25.402353
# 2008-09-12 06:05:00+09:30                NaN   NaN  25.141418
# 2008-09-12 06:10:00+09:30                NaN   NaN  25.015263
# 2008-09-12 06:15:00+09:30                NaN   NaN  24.935015
# ...                                      ...   ...        ...
# 2018-09-04 08:40:00+09:30          73.232483   NaN  16.116261
# 2018-09-04 08:45:00+09:30          73.701248   NaN  16.483055
# 2018-09-04 08:50:00+09:30          74.136238   NaN  16.857719
# 2018-09-04 08:55:00+09:30          74.297318   NaN  17.095589
# 2018-09-04 09:00:00+09:30          74.371704   NaN  17.460459
#
#                            Weather_Relative_Humidity         ghi        dhi  \
# timestamp
# 2008-09-12 05:55:00+09:30                  18.551216    5.227983   2.215820
# 2008-09-12 06:00:00+09:30                  19.242727    5.408280   2.435364
# 2008-09-12 06:05:00+09:30                  19.368038    4.931451   1.885518
# 2008-09-12 06:10:00+09:30                  19.301992    4.298166   1.327833
# 2008-09-12 06:15:00+09:30                  19.123230    4.499399   1.520790
# ...                                              ...         ...        ...
# 2018-09-04 08:40:00+09:30                  31.983961  458.419861  52.726650
# 2018-09-04 08:45:00+09:30                  31.345129  476.982819  53.638588
# 2018-09-04 08:50:00+09:30                  30.324739  495.989990  54.566422
# 2018-09-04 08:55:00+09:30                  29.694036  514.812256  55.702202
# 2018-09-04 09:00:00+09:30                  29.137058  530.577271  56.384224
#
#                            Wind_Direction  Weather_Daily_Rainfall  \
# timestamp
# 2008-09-12 05:55:00+09:30      103.423134                     0.0
# 2008-09-12 06:00:00+09:30      125.776703                     0.0
# 2008-09-12 06:05:00+09:30      163.055115                     0.0
# 2008-09-12 06:10:00+09:30      137.553268                     0.0
# 2008-09-12 06:15:00+09:30      128.099182                     0.0
# ...                                   ...                     ...
# 2018-09-04 08:40:00+09:30       34.989044                     0.0
# 2018-09-04 08:45:00+09:30       35.093048                     0.0
# 2018-09-04 08:50:00+09:30       35.058510                     0.0
# 2018-09-04 08:55:00+09:30       35.023518                     0.0
# 2018-09-04 09:00:00+09:30       34.984627                     0.0
#
#                            Radiation_Global_Tilted  Radiation_Diffuse_Tilted
# timestamp
# 2008-09-12 05:55:00+09:30                      NaN                       NaN
# 2008-09-12 06:00:00+09:30                      NaN                       NaN
# 2008-09-12 06:05:00+09:30                      NaN                       NaN
# 2008-09-12 06:10:00+09:30                      NaN                       NaN
# 2008-09-12 06:15:00+09:30                      NaN                       NaN
# ...                                            ...                       ...
# 2018-09-04 08:40:00+09:30               488.862427                 57.063568
# 2018-09-04 08:45:00+09:30               511.337036                 58.324074
# 2018-09-04 08:50:00+09:30               533.449890                 60.125603
# 2018-09-04 08:55:00+09:30               556.509705                 63.885796
# 2018-09-04 09:00:00+09:30               576.693909                 66.704140
#
# [1049510 rows x 14 columns]

# %%
'''
计算时间间隔
'''
df.power.index.freq
print(df.power.index.freq)
# Out:
# <5 * Minutes>

# %%
'''
将时间间隔转换成s
'''
pd.to_timedelta(df.power.index.freq).total_seconds()
# Out:
# 300.0

# %%
'''
df.power的单位为w
将发电效率数据按照单位计算每小时功率的变化情况
'''
df['energy'] = df.power * pd.to_timedelta(df.power.index.freq).total_seconds()/(3600.0)
print(df.index)
# Out:
# DatetimeIndex(['2008-09-12 05:55:00+09:30', '2008-09-12 06:00:00+09:30',
#                '2008-09-12 06:05:00+09:30', '2008-09-12 06:10:00+09:30',
#                '2008-09-12 06:15:00+09:30', '2008-09-12 06:20:00+09:30',
#                '2008-09-12 06:25:00+09:30', '2008-09-12 06:30:00+09:30',
#                '2008-09-12 06:35:00+09:30', '2008-09-12 06:40:00+09:30',
#                ...
#                '2018-09-04 08:15:00+09:30', '2018-09-04 08:20:00+09:30',
#                '2018-09-04 08:25:00+09:30', '2018-09-04 08:30:00+09:30',
#                '2018-09-04 08:35:00+09:30', '2018-09-04 08:40:00+09:30',
#                '2018-09-04 08:45:00+09:30', '2018-09-04 08:50:00+09:30',
#                '2018-09-04 08:55:00+09:30', '2018-09-04 09:00:00+09:30'],
#               dtype='datetime64[ns, Australia/North]', name='timestamp', length=1049510, freq='5T')

# %%
'''
向pvlib包的location函数中提供经纬度及时区信息（https://en.wikipedia.org/wiki/List_of_tz_database_time_zones）
确定此地区的位置信息，并根据此信息在上面时序df.index的基础上调用get_solarposition获得
太阳的视在天顶角，天顶角，视在仰角，仰角，方位角及随天数变化的时间方程式（EOT）等信息
（详细的计算过程，可查看pvlib里面location和get_solarposition模块的详细code）
'''
loc = pvlib.location.Location(meta['latitude'], meta['longitude'], tz = meta['timezone'])
print(loc)
sun = loc.get_solarposition(df.index)
# Out:
# Location:
#   name: None
#   latitude: -23.762028
#   longitude: 133.874886
#   altitude: 0
#   tz: Australia/North

# %%
print(sun)
# Out:
#                            apparent_zenith     zenith  apparent_elevation  \
# timestamp
# 2008-09-12 05:55:00+09:30        99.878951  99.878951           -9.878951
# 2008-09-12 06:00:00+09:30        98.734162  98.734162           -8.734162
# 2008-09-12 06:05:00+09:30        97.589499  97.589499           -7.589499
# 2008-09-12 06:10:00+09:30        96.445049  96.445049           -6.445049
# 2008-09-12 06:15:00+09:30        95.300898  95.300898           -5.300898
# ...                                    ...        ...                 ...
# 2018-09-04 08:40:00+09:30        64.866505  64.902108           25.133495
# 2018-09-04 08:45:00+09:30        63.802148  63.836124           26.197852
# 2018-09-04 08:50:00+09:30        62.742926  62.775398           27.257074
# 2018-09-04 08:55:00+09:30        61.689144  61.720221           28.310856
# 2018-09-04 09:00:00+09:30        60.641127  60.670904           29.358873
#
#                            elevation    azimuth  equation_of_time
# timestamp
# 2008-09-12 05:55:00+09:30  -9.878951  89.768275          3.652815
# 2008-09-12 06:00:00+09:30  -8.734162  89.267270          3.654044
# 2008-09-12 06:05:00+09:30  -7.589499  88.767496          3.655274
# 2008-09-12 06:10:00+09:30  -6.445049  88.268548          3.656504
# 2008-09-12 06:15:00+09:30  -5.300898  87.770021          3.657734
# ...                              ...        ...               ...
# 2018-09-04 08:40:00+09:30  25.097892  68.938449          0.801226
# 2018-09-04 08:45:00+09:30  26.163876  68.235398          0.802367
# 2018-09-04 08:50:00+09:30  27.224602  67.516092          0.803508
# 2018-09-04 08:55:00+09:30  28.279779  66.779660          0.804650
# 2018-09-04 09:00:00+09:30  29.329096  66.025184          0.805791
#
# [1049510 rows x 6 columns]

# %%
#运用各项同性的天空辐照模型计算了太阳散射辐射（dhi）作用在组件上的辐射量sky
sky = pvlib.irradiance.isotropic(meta['tilt'], df.dhi)
#由ghi和dhi及太阳天顶角计算这一时刻太阳发出的垂直于地面的直接辐射量dni
df['dni'] = (df.ghi - df.dhi)/np.cos(np.deg2rad(sun.zenith))
#基于组件的倾角，方位角，太阳的天顶角和方位角，及垂直于地面的太阳直接辐照度（dni）计算组件上的直接辐照度
beam = pvlib.irradiance.beam_component(meta['tilt'], meta['azimuth'], sun.zenith, sun.azimuth, df.dni)
#组件的实际辐照度=直接辐照度（beam）+散射辐照度（sky）
df['poa'] = beam + sky

# %%
'''
基于组件的实际辐照度，当前的风速情况，环境干球温度，组件的型号（这里组件的型号只有几种可选）
由以上4个参数测算组件的温度
'''
df_temp = pvlib.pvsystem.sapm_celltemp(df.poa, df.wind, df.Tamb, model = meta['temp_model'])
print(df_temp.max())
#确定组件的发热温度
df['Tcell'] = df_temp.temp_cell
# Out:
# temp_cell      1.078089e+57
# temp_module    1.078089e+57
# dtype: float64

# %%
'''
绘制发电实际功率随时间的曲线
'''
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(df.index, df.power, 'o', alpha = 0.01)
ax.set_ylim(0,7000)
fig.autofmt_xdate()
ax.set_ylabel('AC Power (W)');

# %%
'''
获取整体的描述统计信息
'''
df.describe()
# df.head()
# Out:
#                            timestamp  Active_Energy_Delivered_Received  \
# count                        1047588                      1.047588e+06
# mean   2013-09-08 17:09:44.484072192                      4.422405e+04
# min              2008-09-12 05:55:00                      0.000000e+00
# 25%              2011-03-12 09:53:45                      2.150200e+04
# 50%              2013-09-09 09:47:30                      4.402100e+04
# 75%              2016-03-06 21:46:15                      6.724400e+04
# max              2018-09-04 09:00:00                      8.948500e+04
# std                              NaN                      2.609485e+04
#
#        Current_Phase_Average         power  Performance_Ratio           wind  \
# count           1.047588e+06  1.047588e+06      343261.000000  840908.000000
# mean            4.424485e+00  1.021367e+03          42.664523       2.507933
# min             0.000000e+00 -6.600000e+00          -5.810571   -1742.130707
# 25%             3.000000e-01  0.000000e+00           0.000000       1.157206
# 50%             3.000000e-01  0.000000e+00           0.000000       2.251152
# 75%             8.909332e+00  2.169200e+03          71.918808       3.585647
# max             2.273833e+01  5.584967e+03       28701.730470      54.389500
# std             5.725128e+00  1.446838e+03         517.689576       4.364733
#
#                Tamb  Weather_Relative_Humidity           ghi           dhi  \
# count  1.041198e+06               1.041198e+06  1.041198e+06  1.041198e+06
# mean   2.115914e+01               3.989159e+01  2.574431e+02  5.521665e+01
# min   -3.998763e+01               0.000000e+00 -9.856900e+02  0.000000e+00
# 25%    1.456392e+01               2.000851e+01  3.337034e+00  1.200819e+00
# 50%    2.166793e+01               3.311313e+01  8.333547e+00  5.928175e+00
# 75%    2.823161e+01               5.641632e+01  5.075596e+02  7.332887e+01
# max    5.126173e+01               1.028968e+02  2.725606e+03  2.134985e+03
# std    9.639868e+00               2.473027e+01  3.546092e+02  9.137050e+01
#
#        Wind_Direction  Weather_Daily_Rainfall  Radiation_Global_Tilted  \
# count    1.038549e+06            1.041212e+06             4.944740e+05
# mean     2.099647e+01            3.785433e-01             2.765411e+02
# min     -9.999991e+04            0.000000e+00             4.670000e-43
# 25%      1.000107e+02            0.000000e+00             2.614311e+00
# 50%      1.480000e+02            0.000000e+00             8.381646e+00
# 75%      2.404998e+02            0.000000e+00             5.559400e+02
# max      3.015234e+04            6.720000e+01             1.553391e+03
# std      3.729302e+03            2.702038e+00             3.800677e+02
#
#        Radiation_Diffuse_Tilted        energy           dni           poa  \
# count             536601.000000  1.047588e+06  1.041198e+06  1.041198e+06
# mean                  49.938621  8.511390e+01  2.929496e+02  2.748384e+02
# min                   -0.019197 -5.500000e-01 -5.846979e+06  0.000000e+00
# 25%                    1.413757  0.000000e+00 -3.737802e+00  3.381005e+00
# 50%                    2.886025  0.000000e+00 -0.000000e+00  1.031567e+01
# 75%                   70.151932  1.807667e+02  8.136745e+02  5.524648e+02
# max                97322.585940  4.654139e+02  9.387419e+05  5.928905e+05
# std                  246.527936  1.205698e+02  6.807425e+03  6.937596e+02
#
#               Tcell
# count  8.409080e+05
# mean   1.282053e+51
# min   -3.967988e+01
# 25%    1.591248e+01
# 50%    2.514172e+01
# 75%    3.879295e+01
# max    1.078089e+57
# std    1.175656e+54

# %%
'''
根据行的指标获得每一行时间的发电数据
'''
df.iloc[0]
# Out:
# timestamp                           2008-09-12 05:55:00
# Active_Energy_Delivered_Received                    0.0
# Current_Phase_Average                               0.0
# power                                               0.0
# Performance_Ratio                                   NaN
# wind                                                NaN
# Tamb                                           25.73435
# Weather_Relative_Humidity                     18.551216
# ghi                                            5.227983
# dhi                                             2.21582
# Wind_Direction                               103.423134
# Weather_Daily_Rainfall                              0.0
# Radiation_Global_Tilted                             NaN
# Radiation_Diffuse_Tilted                            NaN
# energy                                              0.0
# dni                                           -17.55676
# poa                                            4.955587
# Tcell                                               NaN
# Name: 2008-09-12 05:55:00+09:30, dtype: object

# %%
'''
df的索引是时间序列
索引iloc[0]和loc['2008-11-11 06:00:00+09:30']是等价的
'''
df.loc['2008-11-11 06:00:00+09:30']
# Out:
# timestamp                           2008-11-11 06:00:00
# Active_Energy_Delivered_Received                  516.0
# Current_Phase_Average                             0.806
# power                                         18.866662
# Performance_Ratio                                   NaN
# wind                                                NaN
# Tamb                                                NaN
# Weather_Relative_Humidity                           NaN
# ghi                                                 NaN
# dhi                                                 NaN
# Wind_Direction                                      NaN
# Weather_Daily_Rainfall                              NaN
# Radiation_Global_Tilted                             NaN
# Radiation_Diffuse_Tilted                            NaN
# energy                                         1.572222
# dni                                                 NaN
# poa                                                 NaN
# Tcell                                               NaN
# Name: 2008-11-11 06:00:00+09:30, dtype: object

# %%
'''
筛选出发电功率大于5500kw的发电数据
'''
maxpower=df.power.loc[:]>5500

# %%
#找到最大发电量的发电时间为2014年2月5日12:55
df.loc[maxpower].index[0]
# Out:
# Timestamp('2014-02-05 12:55:00+0930', tz='Australia/North')

# %%
#从08年到18年，10年内每w组件的从早到晚的平均实际发电功率为0.20w
df.power.mean()/5100
# Out:
# 0.20026799795163058

# %%
#通过查询两个维度可以分析其中的相关程度,通过dropna方式去除数据中的Nan数据
df1=df[['power','wind']].dropna(subset=['wind'])['2008-11-14 06:00:00+09:30':'2008-11-14 18:05:00+09:30']

# %%
df1.describe()
# Out:
#              power        wind
# count   146.000000  146.000000
# mean   2301.743666    4.511235
# std    1450.331199    1.188345
# min       0.000000    1.362989
# 25%     802.600086    3.731155
# 50%    2751.850129    4.580558
# 75%    3661.233842    5.262883
# max    4004.333496    7.621149

# %%
'''
绘制发电功率与风速之间的关系曲线
因为发电功率并不是仅仅受到风速的影响，另外从结果看来，这个结果风速对发电功率的影响效果并不明显
'''
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(df1['wind'], df1['power'])
ax.set_xlim(0,10)
# fig.autofmt_xdate()
ax.set_ylabel('Actual power per watt')
ax.set_xlabel('wind speed')
# Out:
# Text(0.5, 0, 'wind speed')

# %%
#按照发电量由大到小进行排序
powerlist=df.power.sort_values(ascending=False)[:1000]

# %%
a=powerlist.index.to_series().apply(lambda x: datetime.datetime.strftime(x, '%b %Y'))
a
# Out:
# timestamp
# 2014-02-05 12:55:00+09:30    Feb 2014
# 2014-02-05 13:00:00+09:30    Feb 2014
# 2011-03-06 13:15:00+09:30    Mar 2011
# 2012-12-18 11:35:00+09:30    Dec 2012
# 2008-11-08 13:50:00+09:30    Nov 2008
#                                ...
# 2016-10-03 12:15:00+09:30    Oct 2016
# 2017-01-17 11:50:00+09:30    Jan 2017
# 2010-10-15 10:55:00+09:30    Oct 2010
# 2013-10-01 10:55:00+09:30    Oct 2013
# 2013-02-18 13:05:00+09:30    Feb 2013
# Name: timestamp, Length: 1000, dtype: object

# %%
month=[]
for each in a:
    month.append(each[:3])

# %%
month
# Out:
# ['Feb',
#  'Feb',
#  'Mar',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Oct',
#  'Feb',
#  'Oct',
#  'Nov',
#  'Nov',
#  'Dec',
#  'Sep',
#  'Mar',
#  'Dec',
#  'Feb',
#  'Nov',
#  'Nov',
#  'Jan',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Dec',
#  'Feb',
#  'Nov',
#  'Jan',
#  'Jul',
#  'May',
#  'Feb',
#  'Feb',
#  'Mar',
#  'Jan',
#  'Aug',
#  'Dec',
#  'Sep',
#  'Sep',
#  'Nov',
#  'Mar',
#  'Feb',
#  'Sep',
#  'Oct',
#  'May',
#  'Feb',
#  'Jan',
#  'Nov',
#  'Sep',
#  'Feb',
#  'Jul',
#  'Oct',
#  'Dec',
#  'Oct',
#  'Feb',
#  'Apr',
#  'Sep',
#  'Feb',
#  'Mar',
#  'Mar',
#  'Apr',
#  'Sep',
#  'May',
#  'Nov',
#  'Sep',
#  'Feb',
#  'Sep',
#  'Mar',
#  'Sep',
#  'May',
#  'Mar',
#  'Nov',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Sep',
#  'Dec',
#  'Sep',
#  'Sep',
#  'Mar',
#  'Sep',
#  'Nov',
#  'Mar',
#  'Dec',
#  'Nov',
#  'Dec',
#  'Sep',
#  'Sep',
#  'Dec',
#  'Dec',
#  'Nov',
#  'Sep',
#  'Sep',
#  'Feb',
#  'Aug',
#  'Sep',
#  'Sep',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Sep',
#  'Feb',
#  'Apr',
#  'Aug',
#  'Feb',
#  'Mar',
#  'Mar',
#  'Nov',
#  'Dec',
#  'Nov',
#  'Nov',
#  'Feb',
#  'Jul',
#  'Sep',
#  'Mar',
#  'Dec',
#  'Feb',
#  'Jan',
#  'Feb',
#  'Mar',
#  'Sep',
#  'Oct',
#  'Oct',
#  'Feb',
#  'Nov',
#  'Oct',
#  'Mar',
#  'Apr',
#  'Feb',
#  'Feb',
#  'Apr',
#  'Sep',
#  'Nov',
#  'Dec',
#  'Sep',
#  'Oct',
#  'Mar',
#  'Dec',
#  'Mar',
#  'Sep',
#  'Oct',
#  'May',
#  'Oct',
#  'Apr',
#  'Mar',
#  'Sep',
#  'Nov',
#  'Dec',
#  'Jan',
#  'Nov',
#  'Oct',
#  'Mar',
#  'Sep',
#  'Jan',
#  'Oct',
#  'Jul',
#  'Nov',
#  'Nov',
#  'Sep',
#  'Jan',
#  'Feb',
#  'Mar',
#  'Sep',
#  'Feb',
#  'Mar',
#  'Jan',
#  'Oct',
#  'Jul',
#  'Sep',
#  'Apr',
#  'Mar',
#  'Sep',
#  'Nov',
#  'Aug',
#  'Oct',
#  'Sep',
#  'Oct',
#  'Mar',
#  'Dec',
#  'Nov',
#  'May',
#  'Apr',
#  'Mar',
#  'Oct',
#  'Feb',
#  'Jan',
#  'Dec',
#  'Oct',
#  'Mar',
#  'Sep',
#  'Apr',
#  'Aug',
#  'May',
#  'Sep',
#  'Feb',
#  'Feb',
#  'Apr',
#  'Oct',
#  'Jun',
#  'Aug',
#  'Jan',
#  'Apr',
#  'May',
#  'Dec',
#  'Apr',
#  'Feb',
#  'Mar',
#  'Apr',
#  'Oct',
#  'Oct',
#  'Apr',
#  'Nov',
#  'Sep',
#  'Nov',
#  'Apr',
#  'Aug',
#  'Oct',
#  'Jan',
#  'Oct',
#  'Nov',
#  'Sep',
#  'Mar',
#  'Sep',
#  'Dec',
#  'May',
#  'Sep',
#  'Dec',
#  'Mar',
#  'Sep',
#  'Dec',
#  'Feb',
#  'Sep',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Nov',
#  'Mar',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Jan',
#  'Nov',
#  'Sep',
#  'Aug',
#  'Jan',
#  'Oct',
#  'Nov',
#  'Apr',
#  'Sep',
#  'Jan',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Mar',
#  'Mar',
#  'Jul',
#  'Dec',
#  'Dec',
#  'Feb',
#  'Sep',
#  'Dec',
#  'Jan',
#  'Mar',
#  'Oct',
#  'Sep',
#  'Nov',
#  'Nov',
#  'Apr',
#  'Aug',
#  'Sep',
#  'Mar',
#  'Sep',
#  'Nov',
#  'Oct',
#  'Feb',
#  'Jan',
#  'Feb',
#  'Mar',
#  'Mar',
#  'Sep',
#  'Apr',
#  'Nov',
#  'Mar',
#  'Mar',
#  'Nov',
#  'Oct',
#  'Mar',
#  'Sep',
#  'Nov',
#  'Apr',
#  'Sep',
#  'Dec',
#  'Nov',
#  'Mar',
#  'Feb',
#  'Sep',
#  'Dec',
#  'Feb',
#  'Apr',
#  'Sep',
#  'Feb',
#  'Oct',
#  'Mar',
#  'Feb',
#  'Dec',
#  'Feb',
#  'Sep',
#  'Feb',
#  'Nov',
#  'Feb',
#  'Feb',
#  'Nov',
#  'Oct',
#  'May',
#  'Aug',
#  'Sep',
#  'Mar',
#  'Jan',
#  'Sep',
#  'Nov',
#  'Apr',
#  'Sep',
#  'Jun',
#  'May',
#  'Aug',
#  'Dec',
#  'Mar',
#  'Oct',
#  'Jun',
#  'Dec',
#  'Jan',
#  'Nov',
#  'Jun',
#  'Dec',
#  'Sep',
#  'Dec',
#  'Dec',
#  'Feb',
#  'Dec',
#  'Sep',
#  'Feb',
#  'Nov',
#  'Mar',
#  'Sep',
#  'Jan',
#  'Mar',
#  'Oct',
#  'Mar',
#  'May',
#  'Sep',
#  'Jun',
#  'Nov',
#  'Jan',
#  'Sep',
#  'Feb',
#  'Jan',
#  'Nov',
#  'Jan',
#  'Oct',
#  'Oct',
#  'Nov',
#  'May',
#  'Sep',
#  'Dec',
#  'Feb',
#  'Mar',
#  'Mar',
#  'Jan',
#  'Aug',
#  'Sep',
#  'Oct',
#  'Oct',
#  'Jul',
#  'Oct',
#  'Dec',
#  'Aug',
#  'Mar',
#  'Jan',
#  'Mar',
#  'Sep',
#  'Mar',
#  'Mar',
#  'Sep',
#  'Aug',
#  'Feb',
#  'Jan',
#  'Sep',
#  'Feb',
#  'Sep',
#  'Dec',
#  'Apr',
#  'Apr',
#  'Nov',
#  'Jan',
#  'Jan',
#  'Sep',
#  'Apr',
#  'Apr',
#  'Sep',
#  'Apr',
#  'Jan',
#  'Feb',
#  'Nov',
#  'Feb',
#  'Nov',
#  'Sep',
#  'Aug',
#  'Sep',
#  'Mar',
#  'Feb',
#  'Oct',
#  'Sep',
#  'Feb',
#  'Apr',
#  'Oct',
#  'Oct',
#  'Feb',
#  'Jan',
#  'Sep',
#  'Mar',
#  'Jul',
#  'Jan',
#  'Mar',
#  'Oct',
#  'Sep',
#  'Aug',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Jan',
#  'Nov',
#  'Oct',
#  'May',
#  'Apr',
#  'Sep',
#  'Nov',
#  'Mar',
#  'Sep',
#  'Jan',
#  'Mar',
#  'Nov',
#  'Jan',
#  'Mar',
#  'Mar',
#  'Apr',
#  'Mar',
#  'Mar',
#  'Nov',
#  'Sep',
#  'Feb',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Jul',
#  'Mar',
#  'Feb',
#  'Dec',
#  'Oct',
#  'Apr',
#  'Feb',
#  'Oct',
#  'May',
#  'Nov',
#  'Mar',
#  'Jan',
#  'Apr',
#  'Mar',
#  'Jan',
#  'Oct',
#  'Apr',
#  'Mar',
#  'Sep',
#  'Dec',
#  'Dec',
#  'Feb',
#  'Apr',
#  'Nov',
#  'Nov',
#  'Mar',
#  'Sep',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Mar',
#  'Feb',
#  'Aug',
#  'Dec',
#  'Oct',
#  'Mar',
#  'Nov',
#  'Mar',
#  'Jan',
#  'Feb',
#  'Dec',
#  'Dec',
#  'Apr',
#  'Apr',
#  'Mar',
#  'Feb',
#  'Feb',
#  'Apr',
#  'Feb',
#  'Sep',
#  'Jun',
#  'Feb',
#  'Sep',
#  'Oct',
#  'Feb',
#  'Nov',
#  'Aug',
#  'Mar',
#  'Feb',
#  'Jan',
#  'Oct',
#  'Dec',
#  'Feb',
#  'Dec',
#  'Dec',
#  'Jan',
#  'Feb',
#  'Aug',
#  'Sep',
#  'Feb',
#  'Apr',
#  'Apr',
#  'Feb',
#  'Oct',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Mar',
#  'Mar',
#  'Sep',
#  'Jan',
#  'Sep',
#  'Feb',
#  'Mar',
#  'May',
#  'Oct',
#  'Nov',
#  'Oct',
#  'Jan',
#  'Sep',
#  'Feb',
#  'Feb',
#  'Nov',
#  'Jun',
#  'Oct',
#  'Jan',
#  'Sep',
#  'Feb',
#  'Feb',
#  'Oct',
#  'Apr',
#  'Sep',
#  'Jul',
#  'Feb',
#  'Oct',
#  'Jun',
#  'Mar',
#  'Oct',
#  'Jul',
#  'Sep',
#  'Jan',
#  'Aug',
#  'Oct',
#  'Aug',
#  'Apr',
#  'Dec',
#  'Sep',
#  'Sep',
#  'Mar',
#  'Feb',
#  'Jan',
#  'Feb',
#  'Jun',
#  'Mar',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Aug',
#  'Feb',
#  'Jan',
#  'Jun',
#  'Oct',
#  'May',
#  'Sep',
#  'Sep',
#  'Nov',
#  'Oct',
#  'Sep',
#  'Mar',
#  'Jan',
#  'May',
#  'Dec',
#  'Jan',
#  'Dec',
#  'Jan',
#  'Feb',
#  'Jan',
#  'Nov',
#  'Sep',
#  'Mar',
#  'Sep',
#  'Apr',
#  'Mar',
#  'Feb',
#  'Sep',
#  'Jan',
#  'Sep',
#  'Dec',
#  'Sep',
#  'Oct',
#  'Sep',
#  'Oct',
#  'Mar',
#  'Jan',
#  'Mar',
#  'Jan',
#  'Jan',
#  'Mar',
#  'Feb',
#  'Mar',
#  'Mar',
#  'Feb',
#  'Jan',
#  'Mar',
#  'Aug',
#  'Nov',
#  'Jan',
#  'Mar',
#  'Aug',
#  'Sep',
#  'Mar',
#  'Mar',
#  'Jan',
#  'Aug',
#  'Oct',
#  'Oct',
#  'Apr',
#  'Mar',
#  'Sep',
#  'Sep',
#  'Apr',
#  'Feb',
#  'May',
#  'Oct',
#  'Mar',
#  'Dec',
#  'Feb',
#  'Oct',
#  'Sep',
#  'Oct',
#  'Jan',
#  'Feb',
#  'Nov',
#  'Oct',
#  'Dec',
#  'Jan',
#  'Sep',
#  'Nov',
#  'Jan',
#  'Feb',
#  'Oct',
#  'Feb',
#  'Sep',
#  'Sep',
#  'Feb',
#  'Oct',
#  'Feb',
#  'Apr',
#  'Dec',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Dec',
#  'Mar',
#  'Nov',
#  'Oct',
#  'Mar',
#  'Jan',
#  'Aug',
#  'Jul',
#  'Jan',
#  'Mar',
#  'Sep',
#  'Jan',
#  'Feb',
#  'Sep',
#  'Sep',
#  'Oct',
#  'Feb',
#  'Feb',
#  'Oct',
#  'Sep',
#  'Apr',
#  'Nov',
#  'Sep',
#  'Sep',
#  'Jan',
#  'Feb',
#  'Oct',
#  'Jun',
#  'Feb',
#  'Nov',
#  'Sep',
#  'Sep',
#  'Jun',
#  'Feb',
#  'Oct',
#  'Oct',
#  'Feb',
#  'Oct',
#  'Oct',
#  'Nov',
#  'Oct',
#  'Mar',
#  'Mar',
#  'Mar',
#  'Oct',
#  'Jan',
#  'May',
#  'Feb',
#  'May',
#  'Aug',
#  'Dec',
#  'Nov',
#  'Apr',
#  'Aug',
#  'Mar',
#  'Feb',
#  'Apr',
#  'Jan',
#  'Jan',
#  'Feb',
#  'Dec',
#  'Sep',
#  'Dec',
#  'Oct',
#  'Dec',
#  'Oct',
#  'Mar',
#  'Jan',
#  'Mar',
#  'Oct',
#  'Dec',
#  'Nov',
#  'Oct',
#  'Oct',
#  'Mar',
#  'Apr',
#  'Oct',
#  'Jan',
#  'Oct',
#  'Apr',
#  'Feb',
#  'Apr',
#  'Oct',
#  'Dec',
#  'Dec',
#  'Dec',
#  'Sep',
#  'Apr',
#  'Sep',
#  'Oct',
#  'Oct',
#  'Mar',
#  'Apr',
#  'Aug',
#  'Feb',
#  'Sep',
#  'Dec',
#  'Dec',
#  'Mar',
#  'Nov',
#  'Jan',
#  'Oct',
#  'Oct',
#  'Nov',
#  'Apr',
#  'Jan',
#  'Oct',
#  'Feb',
#  'Dec',
#  'Apr',
#  'Sep',
#  'Jan',
#  'Oct',
#  'Apr',
#  'Feb',
#  'Apr',
#  'Jan',
#  'Oct',
#  'Jan',
#  'Oct',
#  'Aug',
#  'Nov',
#  'Sep',
#  'Sep',
#  'Nov',
#  'Apr',
#  'Sep',
#  'Nov',
#  'Jul',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Mar',
#  'Sep',
#  'Oct',
#  'Aug',
#  'Oct',
#  'Mar',
#  'Jan',
#  'Feb',
#  'Oct',
#  'Apr',
#  'Dec',
#  'Dec',
#  'Sep',
#  'Sep',
#  'Oct',
#  'Nov',
#  'Nov',
#  'Nov',
#  'Sep',
#  'Sep',
#  'Feb',
#  'Sep',
#  'Feb',
#  'Aug',
#  'Feb',
#  'Nov',
#  'Oct',
#  'Sep',
#  'Oct',
#  'Sep',
#  'Oct',
#  'Sep',
#  'Sep',
#  'Sep',
#  'Mar',
#  'Sep',
#  'Mar',
#  'Oct',
#  'Sep',
#  'Dec',
#  'Feb',
#  'Nov',
#  'Feb',
#  'Jul',
#  'Dec',
#  'Dec',
#  'Feb',
#  'Sep',
#  'Apr',
#  'Dec',
#  'Oct',
#  'Sep',
#  'Oct',
#  'Sep',
#  'Mar',
#  'Jan',
#  'Sep',
#  'Jan',
#  'Dec',
#  'Sep',
#  'Mar',
#  'Apr',
#  'Nov',
#  'Oct',
#  'Feb',
#  'Mar',
#  'Sep',
#  'Oct',
#  'Nov',
#  'Dec',
#  'Dec',
#  'Sep',
#  'Dec',
#  'Dec',
#  'Jan',
#  'Feb',
#  'Sep',
#  'Dec',
#  'Oct',
#  'Nov',
#  'Oct',
#  'Dec',
#  'Aug',
#  'Oct',
#  'Dec',
#  'Feb',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Oct',
#  'Apr',
#  'Mar',
#  'Jan',
#  'Aug',
#  'Jan',
#  'Oct',
#  'Sep',
#  'Aug',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Jan',
#  'Sep',
#  'Jun',
#  'Dec',
#  'Sep',
#  'Oct',
#  'Mar',
#  'Sep',
#  'Oct',
#  'Aug',
#  'Oct',
#  'Sep',
#  'Feb',
#  'Nov',
#  'Feb',
#  'Feb',
#  'Feb',
#  'Dec',
#  'Feb',
#  'Apr',
#  'Sep',
#  'Oct',
#  'Feb',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Oct',
#  'Mar',
#  'Nov',
#  'Apr',
#  'Oct',
#  'May',
#  'Dec',
#  'May',
#  'Jul',
#  'Sep',
#  'Jan',
#  'Dec',
#  'Oct',
#  'Apr',
#  'Jan',
#  'Oct',
#  'Oct',
#  'Oct',
#  'Sep',
#  'Oct',
#  'Sep',
#  'Apr',
#  'Jan',
#  'Feb',
#  'Oct',
#  'Feb',
#  'May',
#  'Oct',
#  'Apr',
#  'Nov',
#  'Feb',
#  'May',
#  'Feb',
#  'Oct',
#  'Dec',
#  'Sep',
#  'Feb',
#  'Mar',
#  'Jul',
#  'Mar',
#  'Jan',
#  'Jan',
#  'Apr',
#  'Mar',
#  'Sep',
#  'Dec',
#  'Jan',
#  'Apr',
#  'Apr',
#  'Sep',
#  'Feb',
#  'Apr',
#  'Oct',
#  'May',
#  'Apr',
#  'Oct',
#  'Feb',
#  'Sep',
#  'Oct',
#  'Jan',
#  'Oct',
#  'Oct',
#  'Feb']

# %%
num={}
for each in month:
    num[each]=month.count(each)
print(num)
type(num)
# Out:
# {'Feb': 132, 'Mar': 116, 'Dec': 89, 'Nov': 93, 'Oct': 147, 'Sep': 168, 'Jan': 93, 'Jul': 16, 'May': 26, 'Aug': 36, 'Apr': 71, 'Jun': 13}
# dict

# %%
season=OrderedDict(sorted(num.items(), key=lambda t: t[1],reverse=True))
season
# Out:
# OrderedDict([('Sep', 168),
#              ('Oct', 147),
#              ('Feb', 132),
#              ('Mar', 116),
#              ('Nov', 93),
#              ('Jan', 93),
#              ('Dec', 89),
#              ('Apr', 71),
#              ('Aug', 36),
#              ('May', 26),
#              ('Jul', 16),
#              ('Jun', 13)])

# %% [markdown]
# 这里列出了发电功率最大的前1000个数据，并按照月份进行了处理。可以看到，9,10两个月的组件的发电效果相对较好，其次是2月和3月。
# 只看月份的话其实意义不大如果果和澳洲的季节结合起来们会发现其实9,10月正好是澳洲的初春时节，而2,3月已经是夏末了谓的发电效率并不直接等同于光照，夏天日照虽强，但是气温较高，反而对组件的发电效率有不良影响。
# 而春初夏末这几个时点的气温也正好在22℃左右，是组件发电的最适宜温度

# %% [markdown]
# # 1:数据标准化
#
# 这一步，我们通过`rdtools.normalize_with_pvwatts()`来对数据进行标准化处理<br>
# pvwatts模型中的数据都已经在上面的分析中得到

# %%
# 提供pvwatts模块所需要的数据
pvwatts_kws = {"poa_global" : df.poa,       #上面进行计算后的组件接受的实际辐照度
              "P_ref" : meta['pdc'],        #系统的装机容量5.1kw
              "T_cell" : df.Tcell,          #监测获得的组件温度
              "G_ref" : 1000,               #标准情况下的参考辐照度
              "T_ref": 25,                  #标准测试情况下的温度25℃
              "gamma_pdc" : meta['tempco']} #线性矩阵下的温度效能系数 1/℃

# 基于pvwatts_kws中的信息，对发电实际功率进行标准化，不同时间光伏的日射量（insolation）也可以同时获得
normalized, insolation = rdtools.normalize_with_pvwatts(df.energy, pvwatts_kws)

#每w组件实际的发电功率，上面的df.energy经修正后除以5100w
#可见大部分组件每w的发电功率都要小于1w，也有一小部分超负荷发电
df['normalized'] = normalized  
#每一个时点的日射量
df['insolation'] = insolation  

# 绘制标准化后的发电功率曲线
fig, ax = plt.subplots(figsize=(8,6))
ax.plot(normalized.index, normalized, 'o', alpha = 0.05)
ax.set_ylim(0,2)
fig.autofmt_xdate()
ax.set_ylabel('Normalized energy(W/W)');

# %% [markdown]
# # 2: 数据过滤
#
# 这一步将过滤掉那些明显不合理的，产生偏差的或者引发巨大“噪声”的数据点
# 同时，rdtools模块也有助于过滤掉那些虽然已经中断，但是还是有低信号输出的数据点。

# %%
# 针对每一个维度的参数进行过滤
nz_mask = (df['normalized'] > 0)                #筛选出发电功率大于0的数据点
poa_mask = rdtools.poa_filter(df['poa'])        #筛选出组件辐射量在200~1200w/m2之间的数据
tcell_mask = rdtools.tcell_filter(df['Tcell'])  #筛选出组件温度在50~100℃之间的数据
clip_mask = rdtools.clip_filter(df['power'])    #过滤掉发电功率过低的点和过高的点

# 上述筛选过后，取以上筛选数据的交集，并提出其中的日射量（insolation）和发电功率（normalized）
filtered = df[nz_mask & poa_mask & tcell_mask & clip_mask]  
filtered = filtered[['insolation', 'normalized']]

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(filtered.index, filtered.normalized, 'o', alpha = 0.05)
ax.set_ylim(0,2)
fig.autofmt_xdate()
ax.set_ylabel('Normalized energy/(w/w)');

# %% [markdown]
# # 3: 数据聚合
#
# 数据点按照辐照度情况进行每日的加权平均计算，降低了由于日出和日落时高误差数据对数据集整体的影响

# %%
#对每日的发电量按照日射量进行加权平均后聚合
daily = rdtools.aggregation_insol(filtered.normalized, filtered.insolation, frequency = 'D')

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(daily.index, daily, 'o', alpha = 0.1)
ax.set_ylim(0,2)
fig.autofmt_xdate()
ax.set_ylabel('Normalized energy/(w/w)');

# %% [markdown]
# # 4: Pr衰减计算
#
# 分析的数据用来代表光伏系统的行为,数据可视化后可见光伏系统的pr衰减情况，这里取置信区间为0.95，进行计算

# %%
# 假设 daily 是包含日期索引和能量值的 Pandas DataFrame
yoy_rd, yoy_ci, yoy_info = rdtools.degradation_year_on_year(daily, confidence_level=95)

# 对计算结果进行可视化
start = daily.index[0]
end = daily.index[-1]
years = (end - start).days / 365.0
y = [1, 1 + (yoy_rd * years)/100]

fig, ax1 = plt.subplots(figsize=(20, 6))  # 修改为只创建一个子图

# 数据点用 o 来表示
ax1.plot(daily.index, daily/yoy_info['renormalizing_factor'], 'o', alpha=0.5, label='Renormalized Energy')
# 用一条黑色虚线回归
ax1.plot([start, end], y, 'k--', linewidth=3, label='Degradation Trend')
ax1.set_xlabel('Date')
ax1.set_ylabel('Renormalized Energy')
ax1.set_ylim(0.5, 1.1)
ax1.legend()  # 添加图例
fig.autofmt_xdate()  # 自动格式化日期

fig.suptitle('Sensor-based degradation results')  # 设置总标题

plt.show()

# %% [markdown]
# 一般组件安装后第一年的衰减会在2.5%左右，此后每年一般维持在0.7%。
# 这样看来这个光伏电站组件的Pr衰减值有95%的可能性介于0.27%-0.6%之间，显然低于一般组件的衰减。
# 由此可以认为此电站运用的组件质量高于市场平均水平
#
# [1] Data Source：Desert Knowledge Australia Centre. Alice Springs. https://dkasolarcentre.com.au/source/alice-springs/dka-m5-b-phase, date accessed: 8/12/2024.<br>
# [2] References：D. Jordan, C. Deline, S. Kurtz, G. Kimball, M. Anderson, "Robust PV Degradation Methodology and Application", IEEE Journal of Photovoltaics, 2024
